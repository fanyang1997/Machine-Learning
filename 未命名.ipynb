# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# get stock info
# print(msft.info)

# get historical market data
hist = msft.history(period="5d")

# %%
hist
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2021-03-11  234.960007  239.169998  234.309998  237.130005  29896000
# 2021-03-12  234.009995  235.820007  233.229996  235.750000  22647900
# 2021-03-15  234.960007  235.190002  231.809998  234.809998  26034900
# 2021-03-16  236.279999  240.059998  235.940002  237.710007  27717700
# 2021-03-17  236.149994  236.589996  234.169998  235.690002   4977562
#
#             Dividends  Stock Splits
# Date
# 2021-03-11          0             0
# 2021-03-12          0             0
# 2021-03-15          0             0
# 2021-03-16          0             0
# 2021-03-17          0             0

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
hist.index
# Out:
# DatetimeIndex(['2021-03-11', '2021-03-12', '2021-03-15', '2021-03-16',
#                '2021-03-17'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
sns.lineplot(hist.index, hist['High'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='High'>

# %%
n_row = 5
n_col = 4
fig, ax = plt.subplots(5, 4, figsize=(15, 8), sharex=True, sharey=True)
for i in range(n_row):
    for j in range(n_col):
#         sns.lineplot(ax=ax[i*3 + j], hist.index, hist['High'])
        sns.lineplot(hist.index, hist["High"], ax=ax[i,j])
#         ax[i, j].xticks(rotation=45)
#         g.set_xticklabels(rotation=30)

# plt.xticks(rotation=45)
